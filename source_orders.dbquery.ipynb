-- %%
create table orders
(
    order_id int,
    order_date date,
    cutomer_id int,
    order_status string
);

insert into orders values (1, '2022-01-01', 1, 'placed');
insert into orders values (2, '2022-01-02', 2, 'shipped');
insert into orders values (3, '2022-01-03', 3, 'delivered');
insert into orders values (4, '2022-01-04', 4, 'cancelled');
insert into orders values (5, '2022-01-05', 5, 'returned');

select * from orders;

--Inserting more data
insert into orders values (6, '2022-01-06', 6, 'placed');
insert into orders values (7, '2022-01-07', 7, 'shipped');
